# %% [markdown]
# # Arethematic Operators

# %%
1 + 8
# Out:
# 9

# %%
4 + 9
# Out:
# 13

# %%
'Hello' + 'Python'
# Out:
# 'HelloPython'

# %%
'Hello' + 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 'Hello' + 7
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Concatinate

# %%
9 + 9.5 # int + float
# Out:
# 18.5

# %%
6 - 3
# Out:
# 3

# %%
10 / 2
# Out:
# 5.0

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
10 * 7
# Out:
# 70

# %%
'Hello' * 5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
# Module

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# # Comparision Operators

# %%
10 > 8
# Out:
# True

# %%
5 < 9
# Out:
# True

# %%
5 > 9
# Out:
# False

# %%
5 > 5
# Out:
# False

# %%
6 < 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 != 8
# Out:
# True

# %%
'Hello' != 'Python'
# Out:
# True

# %%
'Hello' != 'Hello'
# Out:
# False

# %%
'Exit' == 'Exit'
# Out:
# True

# %%
'Exit' != 'Exit'
# Out:
# False

# %%
5 > 1 and 10 > 5
# Out:
# True

# %%
5 > 1 and 10 < 5
# Out:
# False

# %%
5 > 1 or 10 < 5
# Out:
# True

# %% [markdown]
# # Operatons

# %%
age = 80
print('My age is', age)
# Out:
# My age is 80

# %%
print(f'Your age is {age} thank you')
# Out:
# Your age is 80 thank you

# %%
print('Hello', 92, 10.5, True)
# Out:
# Hello 92 10.5 True

# %%
a = 1,2,3,4,5

# %%
x,y,z = 10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
a = 1,2,3,4,5

# %%
a
# Out:
# (1, 2, 3, 4, 5)

# %%
f_name = input('Enter your f_name')
l_name = input('Enter your l_name')
print(f'Your first name is {f_name} and last name is {l_name}')
# Out:
# Enter your f_name Ram
# Enter your l_name Sham
# Your first name is Ram and last name is Sham

# %%
age = input('Enter your age')
print(f'Your name is {f_name} and your age is {age}')
# Out:
# Enter your age 87
# Your name is Ram and your age is 87

# %%
type(age)
# Out:
# str

# %%
'87'
# Out:
# '87'

# %%
type('87')
# Out:
# str

# %% [markdown]
# # Typecasting

# %%
age = int(input())

# %%
l = '800'

# %%
type(l)
# Out:
# str

# %%
int(l)
# Out:
# 800

# %%
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
str(100)
# Out:
# '100'

# %%
age = int(input('Enter your age'))
type(age)
# Out:
# Enter your age 60
# int
