# %%
square(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 square(3)
#
# NameError: name 'square' is not defined

# %%
even_odd(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 evn_odd(7)
#
# NameError: name 'evn_odd' is not defined

# %%
import all_functions

# %%
all_functions.test(1,2,23,4)
# Out:
# (1, 2, 23, 4)

# %%
all_functions.int_filter(1,1.5,'Hello',True,31,False)
# Out:
# [1, 31]

# %%
from notepad import test2

# %%
test2(1,6)
# Out:
# 0.16666666666666666

# %%
import numpy

# %%
numpy.mean([123,423,6323])
# Out:
# 2289.6666666666665

# %%
import functions as gemini
# Out:
# 49
# 21

# %%
gemini.add()

# %%
import pandas as pd

# %%
# 5 modules
# all functions --> 
# last --> use
