# %%
a = 10 
b = 40

# %%
a + b
# Out:
# 50

# %%
name = 'Om'

# %%
print('My name is ' + name)
# Out:
# My name is Om

# %%
age = 50

# %%
print('My age is ', age)
# Out:
# My age is  50

# %%
# F formating

# %%
mobile_num = 923184309218

# %%
print(f'My name is {name} and my age is {age} and my mobile num is {mobile_num}')
# Out:
# My name is Om and my age is 50 and my mobile num is 923184309218

# %%
print(f'My name is {4} and my age is {42} and my mobile num is {8674328764}')
# Out:
# My name is 4 and my age is 42 and my mobile num is 8674328764

# %% [markdown]
# # user input

# %%
first_name = input('Write your first name')
last_name = input('Write your last name')
print(f'My first name is {first_name} and last name is {last_name}')
# Out:
# Write your first name Om
# Write your last name dixit
# My first name is Om and last name is dixit

# %%
age = input('Enter your age')
print(f'My age is {age}')
# Out:
# Enter your age 32
# My age is 32

# %%
type(age)
# Out:
# str

# %%
age
# Out:
# '32'

# %%
age = int(input('Mension your age'))
print(f'My age is {age}')
# Out:
# Mension your age 63
# My age is 63

# %%
type(age)
# Out:
# int

# %%
number = int(input('Mobile number'))
# Out:
# Mobile number 7.9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 number = int(input('Mobile number'))
#
# ValueError: invalid literal for int() with base 10: '7.9'

# %%
x = 'code'

# %%
'python'.capitalize()
# Out:
# 'Python'

# %%
'python'.count('o')
# Out:
# 1

# %%
'python'.isnumeric()
# Out:
# False

# %%
'10'.isnumeric()
# Out:
# True

# %%
'python'.split('t')
# Out:
# ['py', 'hon']

# %%
'Today we are learning about basic python'.split(' ')
# Out:
# ['Today', 'we', 'are', 'learning', 'about', 'basic', 'python']

# %%
'python'.istitle()
# Out:
# False

# %%
'Hello'.istitle()
# Out:
# True

# %%
'Hello'.islower()
# Out:
# False

# %%
'hello'.islower()
# Out:
# True

# %%
'python'.upper()
# Out:
# 'PYTHON'

# %%
course = input('Course name')
course == 'java'
# Out:
# Course name JAVA
# False

# %%
course.lower() == 'java'
# Out:
# True

# %%
'hello'.center(10,'*')
# Out:
# '**hello***'

# %%
'h'.center(11, '$')
# Out:
# '$$$$$h$$$$$'

# %%
'Hello'.join('e')
# Out:
# 'e'

# %%
'hello'.join('Python')
# Out:
# 'Phelloyhellothellohhelloohellon'

# %%
''.join('Python')
# Out:
# 'Python'

# %%
num = 263532

# %%
list(str(num))
# Out:
# ['2', '6', '3', '5', '3', '2']

# %%
a,b,c = 10,20,30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
nums = 10,20,30,40,50

# %%
nums
# Out:
# (10, 20, 30, 40, 50)

# %%
n = 10
s1 = (n * (n+1)) / 2

# %%
s1
# Out:
# 55.0

# %% [markdown]
# # List

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
type(l)
# Out:
# list

# %%
mix = [1.5, 10, True, 'Python', 10+5j]

# %%
mix
# Out:
# [1.5, 10, True, 'Python', (10+5j)]

# %% [markdown]
# # Indexing

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l[1]
# Out:
# 2

# %%
mix
# Out:
# [1.5, 10, True, 'Python', (10+5j)]

# %%
mix[3]
# Out:
# 'Python'

# %%
mix[-2]
# Out:
# 'Python'

# %%
x
# Out:
# 'code'

# %%
x[0]
# Out:
# 'c'

# %%
x[1]
# Out:
# 'o'

# %%
mix
# Out:
# [1.5, 10, True, 'Python', (10+5j)]

# %%
mix[0:3]  # start index : end_value + 1
# Out:
# [1.5, 10, True]

# %%
mix[1:4]
# Out:
# [10, True, 'Python']

# %%
mix[2:-1]
# Out:
# [True, 'Python']

# %%
mix[2:5]
# Out:
# [True, 'Python', (10+5j)]

# %%
mix[:]
# Out:
# [1.5, 10, True, 'Python', (10+5j)]

# %%
mix[2:]
# Out:
# [True, 'Python', (10+5j)]

# %%
mix[:3]
# Out:
# [1.5, 10, True]
