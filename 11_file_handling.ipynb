# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B608-DCBC
#
#  Directory of C:\Users\bhosa\Downloads\707\Python\Advaned
#
# 15-06-2026  16:03    <DIR>          .
# 15-06-2026  16:03    <DIR>          ..
# 15-06-2026  15:22    <DIR>          .ipynb_checkpoints
# 15-06-2026  15:22                26 hello.txt
# 15-06-2026  15:36               655 multiline.txt
# 15-06-2026  15:27                88 test1.txt
# 15-06-2026  15:33               125 test2.txt
# 15-06-2026  15:43               133 test3.txt
# 15-06-2026  16:03            47,793 Untitled.ipynb
#                6 File(s)         48,820 bytes
#                3 Dir(s)  21,106,724,864 bytes free

# %%
f = open('hello.txt',mode='r')

# %%
f = open('hello.txt',mode='r+')

# %%
f = open('hello.txt',mode='w')

# %%
f.write("This is my hello txt file.")
# Out:
# 26

# %%
f.close()

# %%
file = open('hello.txt',mode='r')

# %%
file.read()This is my hello txt file.'
# Out:
#   Cell In[8], line 1
#     file.read()This is my hello txt file.'
#                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
file.read()

# %%
file.seek(0)

# %%
file.read()

# %%
file.seek(4)

# %%
file.read()

# %%
f.close()

# %%
f = open('test1.txt', mode='w')

# %%
f.write('We are learning file handling in python.')

# %%
f.write('Today we will go to movie')

# %%
f.close()

# %%
f = open('test1.txt', 'r+')

# %%
f.read()

# %%
f.write('This is my new sentence')

# %%
f.read()

# %%
f.seek(0)

# %%
f.read()

# %%
f.seek(0)

# %%
f.write('Hello how are you')

# %%
f.seek(0)

# %%
f.read()

# %%
f.close()

# %%
f = open('test2.txt', mode='w')

# %%
f.write('This is my first sentence')

# %%
f.close()

# %%
f = open('test2.txt', mode='r+')

# %%
f.read()

# %%
f.write('This is my second sentence.')

# %%
f.seek(0)

# %%
f.read()

# %%
f.seek(0)

# %%
f.write('Note')

# %%
f.seek(0)

# %%
f.read()

# %%
f.write('This is my third sentence')

# %%
f.seek(0)

# %%
f.read()

# %%
f.write('This is my fourth sentence.')

# %%
f.seek(0)

# %%
f.read()

# %%
f.write('Hello my name is xyz.')

# %%
f.seek(0)

# %%
f.readline()

# %%
f.close()

# %%
f = open('multiline.txt',mode='w')

# %%
f.write("""We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.

Read more

Today we’re launching Claude Fable 5: a Mythos-class1 model that we’ve made safe for general use.

Fable 5’s capabilities exceed those of any model we’ve ever made generally available. It is state-of-the-art on nearly all tested benchmarks of AI capability, showing exceptional performance in software engineering, knowledge work, vision, scientific research, and many other areas. The longer and more complex the task, the larger Fable 5’s lead over our other models.""")

# %%
f.close()

# %%
f = open('multiline.txt',mode='r+')

# %%
f.readline()

# %%
f.seek(0)

# %%
print(f.readline())

# %%
f.seek(0)

# %%
f.readline()

# %%
f.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 f.readline()
#
# ValueError: I/O operation on closed file.

# %%
f.readline()

# %%
f.readline()

# %%
f.readline()

# %%
f.readline()

# %%
f.readline()

# %%
f.readline()

# %%
f.seek(0)

# %%
f.read()

# %%
f.seek(0)

# %%
f.readlines()

# %%
f.close()

# %%
f = open('test3.txt',mode='w')

# %%
f.write("""Today we are learning file handling.
We are preparing for full stack data science.
I am expert in machine learning.
AI is amazing.""")
# Out:
# 130

# %%
f.close()

# %%
f = open('test3.txt', mode='r+')

# %%
f.read()
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Today we are learning file handling.\n'

# %%
f.readline()
# Out:
# 'We are preparing for full stack data science.\n'

# %%
f.readline()
# Out:
# 'I am expert in machine learning.\n'

# %%
f.readline()
# Out:
# 'AI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['Today we are learning file handling.\n',
#  'We are preparing for full stack data science.\n',
#  'I am expert in machine learning.\n',
#  'AI is amazing.']

# %%
f.seek(0)
# Out:
# 0

# %%
for sentence in f.readlines():
    print(sentence)
# Out:
# Today we are learning file handling.
#
# We are preparing for full stack data science.
#
# I am expert in machine learning.
#
# AI is amazing.

# %%
for sentence in f.readlines():
    print(sentence.split(' '))

# %%
f.seek(0)
# Out:
# 0

# %%
for sentence in f.readlines():
    print(f.readline())

# %%
f.seek(0)
# Out:
# 0

# %%
l = []
for word in f.readline():
    print(l.append(word))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
l
# Out:
# ['T',
#  'o',
#  'd',
#  'a',
#  'y',
#  ' ',
#  'w',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'f',
#  'i',
#  'l',
#  'e',
#  ' ',
#  'h',
#  'a',
#  'n',
#  'd',
#  'l',
#  'i',
#  'n',
#  'g',
#  '.',
#  '\n']

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Today we are learning file handling.\n'

# %%
for i in 'Today we are learning file handling.\n':
    print(i)
# Out:
# T
# o
# d
# a
# y
#
# w
# e
#
# a
# r
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# f
# i
# l
# e
#
# h
# a
# n
# d
# l
# i
# n
# g
# .

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
text = f.read()

# %%
text
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
text =  text.split('\n')

# %%
text
# Out:
# ['Today we are learning file handling.',
#  'We are preparing for full stack data science.',
#  'I am expert in machine learning.',
#  'AI is amazing.']

# %%
for i in text:
    print(i)
# Out:
# Today we are learning file handling.
# We are preparing for full stack data science.
# I am expert in machine learning.
# AI is amazing.

# %%
for i in text:
    print(i.split('.'))
# Out:
# ['Today we are learning file handling', '']
# ['We are preparing for full stack data science', '']
# ['I am expert in machine learning', '']
# ['AI is amazing', '']

# %%
l2 = []
for i in text:
    print(l2.append(i.replace('.','')))
# Out:
# None
# None
# None
# None

# %%
'hello.'.replace('.','')
# Out:
# 'hello'

# %%
l2
# Out:
# ['Today we are learning file handling',
#  'We are preparing for full stack data science',
#  'I am expert in machine learning',
#  'AI is amazing']

# %%
for i in l2:
    print(i.split(' '))
# Out:
# ['Today', 'we', 'are', 'learning', 'file', 'handling']
# ['We', 'are', 'preparing', 'for', 'full', 'stack', 'data', 'science']
# ['I', 'am', 'expert', 'in', 'machine', 'learning']
# ['AI', 'is', 'amazing']

# %%
words = []
for i in l2:
    words.extend(i.split(' '))

# %%
words
# Out:
# ['Today',
#  'we',
#  'are',
#  'learning',
#  'file',
#  'handling',
#  'We',
#  'are',
#  'preparing',
#  'for',
#  'full',
#  'stack',
#  'data',
#  'science',
#  'I',
#  'am',
#  'expert',
#  'in',
#  'machine',
#  'learning',
#  'AI',
#  'is',
#  'amazing']

# %%
words.count('is')
# Out:
# 1

# %%
for i in words:
    print(i,words.count(i))
# Out:
# Today 1
# we 1
# are 2
# learning 2
# file 1
# handling 1
# We 1
# are 2
# preparing 1
# for 1
# full 1
# stack 1
# data 1
# science 1
# I 1
# am 1
# expert 1
# in 1
# machine 1
# learning 2
# AI 1
# is 1
# amazing 1
