# %% [markdown]
# # Data Types

# %% [markdown]
# # Int

# %% [raw]
# int ---> Complete number
# eg: No of family members
# ---> 4,3,5

# %%
2
# Out:
# 2

# %%
type(5)
# Out:
# int

# %% [markdown]
# # Float

# %% [raw]
# float ---> Values in decimal format
# Eg : Weight --> 56.300, 80.200

# %%
6.2
# Out:
# 6.2

# %%
type(6.2)
# Out:
# float

# %%
type(5.0)
# Out:
# float

# %%
type(5)
# Out:
# int

# %% [markdown]
# # String

# %% [raw]
# string is used to write words sentences
# rules
# single line ---> ' '   " "
# multiple line ---> ''' '''     """ """

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(6)
# Out:
# 6

# %%
'''This is my first day.
I am learning data types.
I am enjoying data science.'''
# Out:
# 'This is my first day.\nI am learning data types.\nI am enjoying data science.'

# %%
print('''This is my first day.
I am learning data types.
I am enjoying data science.''')
# Out:
# This is my first day.
# I am learning data types.
# I am enjoying data science.

# %% [markdown]
# # Boolean

# %%
1 > 0
# Out:
# True

# %%
1 > 8
# Out:
# False

# %% [markdown]
# # Variables

# %%
a = 5

# %%
b = 7

# %%
a + b
# Out:
# 12

# %%
5 = 730
# Out:
#   Cell In[17], line 1
#     5 = 730
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a5 = 730

# %%
first name = 'python'
# Out:
#   Cell In[19], line 1
#     first name = 'python'
#           ^
# SyntaxError: invalid syntax

# %%
first_name = 'python'

# %%
first_name
# Out:
# 'python'

# %%
type = 60

# %%
type
# Out:
# 60

# %%
type(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 type(7)
#
# TypeError: 'int' object is not callable
